# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.read_csv('ACME-HappinessSurvey2020.csv')
df.head()
# Out:
#    Y  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %%
X = df[['X1','X2','X3','X4','X5']]
y = df['Y']

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=5)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(max_depth=1, min_samples_split=2, min_samples_leaf=1)
clf = clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
accuracy*100
# Out:
# 75.0

# %% [markdown]
# We achieved 75% accuracy rate with decision tree algorithm.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
scaled_X = scaler.transform(X)
scaled_X.shape
# Out:
# (126, 5)

# %%
from sklearn.decomposition import PCA
x_pca = PCA(n_components = 5)
x_pca.fit(scaled_X)
B = x_pca.transform(scaled_X)
PCA_X = pd.DataFrame(B)
PCA_X
# Out:
#             0         1         2         3         4
# 0    1.522364  1.526120 -0.709380 -0.272355  0.127910
# 1    0.276073  0.641599 -2.051797  0.375213 -0.665478
# 2    0.347531 -0.164476  1.247598  0.079337  0.561232
# 3    0.162270  0.537470  1.722620  0.303071  0.470684
# 4    0.162270  0.537470  1.722620  0.303071  0.470684
# 5   -1.923504  1.404908  0.518876  1.799219 -0.111436
# 6    3.824815 -0.460741  0.025004 -0.935739  0.140129
# 7   -1.300697  0.772372  0.849564  0.117876  0.247197
# 8   -0.163665 -0.794862 -1.162311 -0.812181 -0.213078
# 9   -0.262818  0.349521  1.857486 -0.708102 -1.907599
# 10   2.176587  0.476107 -0.373031 -0.897200 -0.173906
# 11  -0.206736  1.158820  0.296428  0.680425 -0.507020
# 12  -1.880432 -0.548774 -0.939863  0.306612  0.182506
# 13  -0.817888  0.255151 -1.498660 -0.187336  0.088738
# 14   0.818008 -1.295085 -0.317267 -0.391890 -0.627740
# 15   0.701286  0.097621 -0.462727 -1.248410 -1.427908
# 16  -1.584399  0.418493 -0.436829  0.295251  0.730108
# 17  -0.275953 -1.681533  0.235870 -0.954439  0.126476
# 18   0.280507 -1.637778 -0.508156  1.089476  0.474243
# 19  -0.348926 -0.092916 -0.687289 -0.588447 -0.303626
# 20   0.632747 -0.593139  0.157755 -0.168155 -0.718288
# 21  -1.997154  0.843932 -1.085323 -0.549908 -0.617662
# 22  -1.997154  0.843932 -1.085323 -0.549908 -0.617662
# 23   0.774134 -0.759069 -1.263504  1.020394  2.142907
# 24   0.928781  0.374128  0.660789 -0.179516 -0.170686
# 25   1.806065  1.879999  0.577013 -0.449730 -0.355002
# 26  -0.390482  1.078224 -1.604787  0.834044 -1.394176
# 27   2.535453  0.608419  0.141325  1.204436 -0.947200
# 28   2.535453  0.608419  0.141325  1.204436 -0.947200
# 29  -0.615058 -0.695118  1.191575  0.549529 -0.715067
# ..        ...       ...       ...       ...       ...
# 96   0.274558  1.424141  0.324440  0.445329  0.131130
# 97  -2.294703  0.659207  0.787880 -0.468430 -0.368655
# 98   0.645080  0.020249 -0.625604 -0.002141  0.312226
# 99   1.072486  0.843322 -0.731731  1.019240 -1.170688
# 100 -0.386048 -1.201154 -0.061145  1.548307 -0.254454
# 101 -0.646474 -0.277641  1.185914 -0.506969 -0.054619
# 102  0.532792 -0.866422  0.772577 -0.144398  0.651780
# 103 -0.052892  0.874351 -0.184255 -0.599808  0.243976
# 104  0.361379 -0.333630 -1.911998  0.175235  0.795137
# 105 -0.757248 -1.946854  0.207858 -0.719343 -0.511674
# 106 -1.269959 -1.794698  0.174185 -1.540745 -0.489375
# 107 -0.348926 -0.092916 -0.687289 -0.588447 -0.303626
# 108 -1.411470 -0.896841 -0.128491 -0.094498 -0.209858
# 109 -1.115437  0.070426  0.374542 -0.105859  0.337744
# 110 -0.602725 -0.081730  0.408215  0.715543  0.315446
# 111 -0.602725 -0.081730  0.408215  0.715543  0.315446
# 112  1.299303 -1.029764 -0.289255 -0.626986  0.010410
# 113 -0.744915 -1.333466 -0.575501 -0.553329  0.518840
# 114  0.095246 -0.935832 -0.033134  1.313210  0.383696
# 115 -2.109442 -0.042739  0.312858 -0.692165 -0.278107
# 116  0.836725  2.993610 -1.051391 -0.704008  1.090174
# 117 -2.207883 -1.098564 -1.448558 -0.738525  0.295352
# 118 -0.021475  0.456874 -0.178594  0.456690 -0.416472
# 119  0.977767 -0.291673  3.831708  1.837582 -1.725487
# 120  0.724437  2.106939  0.346790 -0.846265  1.429728
# 121 -0.417465 -0.783676 -0.066807  0.491808  0.405994
# 122  0.545125 -0.253034 -0.010783  0.021616  1.682293
# 123 -0.602725 -0.081730  0.408215  0.715543  0.315446
# 124 -0.021475  0.456874 -0.178594  0.456690 -0.416472
# 125 -1.040271 -0.151141 -0.397495  2.173152  0.047362
#
# [126 rows x 5 columns]

# %%
print(x_pca.explained_variance_ratio_)
# Out:
# [0.38754134 0.20657685 0.17690278 0.12681667 0.10216235]

# %% [markdown]
# Using the PCA method, we showed which column carries how much information.
